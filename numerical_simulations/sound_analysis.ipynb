# %%
from fourier import *

import numpy as np 
import seaborn as sns
from pydub import audio_segment
data = audio_segment.from_file("real_guitar_pluck.wav",)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 6
#       4 import seaborn as sns
#       5 from pydub import audio_segment
# ----> 6 data = audio_segment.from_wav("real_guitar_pluck.wav",)
#
# AttributeError: module 'pydub.audio_segment' has no attribute 'from_wav'

# %%
sns.lineplot(data)
# Out:
# <Axes: >
